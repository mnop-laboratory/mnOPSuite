# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
d=np.loadtxt('100x100 microns dirt particle.txt')

# %%
plt.imshow(d)
plt.colorbar()
plt.clim(.02,.04)

# %%
from scipy.optimize import minimize

# %%
minimize?

# %%
p0=np.random.randn(100,100)
idx,idy=np.ogrid[0:1:100j,0:1:100j]
poffset=idx*.1+idy*.1

# %%
pwd
# Out:
# 'C:\\Users\\mnopl\\Desktop\\Software\\LabVIEW\\PRISM Scanning\\Benchmarking data'

# %%
reload(ps)
# Out:
# <module 'prism_scanning' from 'C:\\Users\\mnopl\\Desktop\\Software\\LabVIEW\\PRISM Scanning\\prism_scanning.py'>

# %%
import prism_scanning as ps
from scipy.optimize import minimize,leastsq
ptrue=np.random.randn(100,100)
poffset=ps.phase_level(ptrue,5,5,0)
poffset[30:]=0
plt.imshow(poffset)
plt.colorbar()

kwargs=dict(ftol=1e-12,xtol=1e-12)
plt.figure()
plt.imshow(ps.auto_phase_level(poffset,0,-10,0,**kwargs))

# %%
def to_minimize(args):
    
    pnew=ps.phase_level(poffset,*args)
    return (ptrue-pnew).flatten()

to_minimize((-5,-5,0))
# Out:
# array([ 2.77555756e-17, -4.44089210e-16,  6.66133815e-16, ...,
#        -3.88578059e-16, -2.22044605e-16, -5.55111512e-16])

# %%
leastsq(to_minimize,(0,0,0))
# Out:
# (array([-4.9946624 , -5.01272812,  6.28625225]), 3)

# %%
plt.imshow(ps.auto_phase_level(poffset,0,-5,0))

# %%
from importlib import reload

# %%
reload(ps)
# Out:
# <module 'prism_scanning' from 'C:\\Users\\mnopl\\Desktop\\Software\\LabVIEW\\PRISM Scanning\\prism_scanning.py'>

# %%
plt.imshow()
